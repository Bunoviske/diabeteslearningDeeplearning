# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.basics import *
from fastai.callback.all import *
from fastai.vision.all import *
import torch
from PIL import Image

#Para rodar no meu pc a VM Instance
#gcloud compute ssh jupyter@my-fastai-instance -- -L 8080:localhost:8080

# Testar to_fp16, size diferente, ir fazendo transfer learning de sizes diferentes, fine_tunning
# Out:
# C:\Users\bruno\miniconda3\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # DATA

# %% [markdown]
# ### Dataset

# %%
path = './database'
path_anno = path + '/gt'
path_img = path + '/done'

#funcao que pega a imagem de anotacoes correspondente, dado a imagem original de entrada
get_y_fn = lambda x : path_anno + '/' + f'{x.stem}_GT.png'

# %%
np.random.seed(2) #mesma semente para todas as vezes que executar

label_fnames = get_image_files(path_anno)
print(label_fnames[:3])
fnames = get_image_files(path_img)
print(fnames[:3])
# Out:
# [Path('database/gt/0_GT.png'), Path('database/gt/1004_GT.png'), Path('database/gt/1005_GT.png')]
# [Path('database/done/0.jpg'), Path('database/done/1.jpg'), Path('database/done/10.jpg')]

# %%
#redimensiona todas as imagens e salva novamente

# CUIDADO PARA NAO REDIMENSIONAR AS IMAGENS ORIGINAIS ANOTADAS. SEMPRE REDIMENSIONAR UMA COPIA DELAS
sizeImage = (512,512)

for file in fnames:
    image = Image.open(file)
    image = image.resize(sizeImage, resample=Image.NEAREST)
    image.save(file)

for file in label_fnames:
    image = Image.open(file)
    image = image.resize(sizeImage, resample=Image.NEAREST)
    image.save(file)

# %%
### VISUALIZACAO DA MÁSCARA FICA COM A BORDA ESTRANHA, MAS ELA ESTÁ CORRETA COMO PODE SER VISTO NOS CODIGOS DO GROUND TRUTH

idx = 1
cmap = matplotlib.colors.ListedColormap (np.random.rand(256,3))

img = Image.open(fnames[idx])
arr = np.asarray(img)
plt.imshow(arr)
plt.show()

img1 = Image.open(get_y_fn(fnames[idx]))
arr = np.asarray(img1)
plt.imshow(arr, cmap=cmap, vmin=0, vmax=255)
plt.show()
print("Ground truth Codes",np.unique(arr,return_counts=True))
# Out:
# Ground truth Codes (array([ 0,  3, 50, 58, 65, 73, 74], dtype=uint8), array([62817, 28087, 17105, 32878, 30944, 14437, 30797], dtype=int64))

# %%
codes = np.loadtxt(path + '/' + 'classesNumber.txt', dtype=str, delimiter='\n',encoding='utf')
codes = [code.split(": ")[1] for code in codes] #pega apenas o nome de cada classe e ignora o ID

# %%
# free = gpu_mem_get_free_no_cache()
# # the max size of bs depends on the available GPU RAM
# if free > 8200: bs=8
# else:           bs=4
# print(f"using bs={bs}, have {free}MB of GPU RAM free")

bs = 1 # batch size
size = np.array([350, 350]) # image size (360,480)
print(size)
# Out:
# [350 350]

# %% [markdown]
# ### Transformations

# %%
# tfms = aug_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
tfms = aug_transforms(flip_vert=True, size=size)

# %% [markdown]
# ### DataBunch

# %%
dataloaders = SegmentationDataLoaders.from_label_func(path, bs=bs,
    fnames = fnames[0:3], 
    label_func = get_y_fn,                                     
    codes = codes,   
    valid_pct=0.2,
    seed=None,                
    batch_tfms=[*tfms, Normalize.from_stats(*imagenet_stats)])

dataloaders.vocab = codes
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
len(dataloaders.train_ds), len(dataloaders.valid_ds)
# Out:
# (3, 0)

# %%
dataloaders.show_batch(max_n=4, figsize=(5, 5), cmap=cmap)

# %% [markdown]
# # TRAINING

# %%
void_code = 0

def acc_segmentation(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# def dice_segmentation(input:Tensor, targs:Tensor, iou:bool=True)->Rank0Tensor:
#     "Dice coefficient metric for binary target. If iou=True, returns iou metric, classic for segmentation problems."
#     n = targs.shape[0]
#     mask = targs != void_code
#     input = input.argmax(dim=1)[mask]#.view(n,-1)
#     targs = targs[mask]#.view(n,-1)
#     intersect = (input * targs).sum().float()
#     union = (input+targs).sum().float()
#     if not iou: return (2. * intersect / union if union > 0 else union.new([1.]).squeeze())
#     else: return intersect / (union-intersect+1.0)

dice_segmentation = partial(dice, iou=True)

# %%
wd=1e-3
learn = unet_learner(data, models.resnet34, metrics=[acc_segmentation,dice_segmentation], wd=wd, callback_fns=ShowGraph).to_fp16()

# %%
learn.model[0].load_state_dict(torch.load(path + '/../resnet34_encoder-food101.h5'), strict=True); #load preTrained from FOOD101

# %%
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.10E-04

# %%
# lr = 1e-4 # loss 3.8 para wd 1e-4
lr = 3e-4 # loss 2.4 para wd 1e-3
# lr = 1e-4 # loss 4.5 para wd 1e-2

# %%
learn.fit_one_cycle(100, lr, pct_start=0.9,
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='acc_segmentation',
                                                 name='stage-1-best')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_segmentation</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.164115</td>
#       <td>2.610966</td>
#       <td>0.014606</td>
#       <td>-1.783628</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.783397</td>
#       <td>2.244922</td>
#       <td>0.001092</td>
#       <td>0.614231</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.539196</td>
#       <td>2.009143</td>
#       <td>0.007187</td>
#       <td>2.293310</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.325680</td>
#       <td>1.757185</td>
#       <td>0.032028</td>
#       <td>-1.783989</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.155766</td>
#       <td>1.661120</td>
#       <td>0.055684</td>
#       <td>-1.429157</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.017273</td>
#       <td>1.580468</td>
#       <td>0.074272</td>
#       <td>-1.433513</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.898935</td>
#       <td>1.505672</td>
#       <td>0.101376</td>
#       <td>-1.424613</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.802062</td>
#       <td>1.436480</td>
#       <td>0.145762</td>
#       <td>-1.444349</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.723095</td>
#       <td>1.419760</td>
#       <td>0.188549</td>
#       <td>-1.395729</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.636701</td>
#       <td>1.349162</td>
#       <td>0.221339</td>
#       <td>-1.404862</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.572813</td>
#       <td>1.316225</td>
#       <td>0.280991</td>
#       <td>-1.382105</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.500226</td>
#       <td>1.163642</td>
#       <td>0.346114</td>
#       <td>-1.355948</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.427449</td>
#       <td>1.174822</td>
#       <td>0.341858</td>
#       <td>-1.386320</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.352355</td>
#       <td>1.045385</td>
#       <td>0.409135</td>
#       <td>-1.377256</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.282032</td>
#       <td>1.043363</td>
#       <td>0.436897</td>
#       <td>-1.286249</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.206602</td>
#       <td>0.968724</td>
#       <td>0.481898</td>
#       <td>-1.301038</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.166621</td>
#       <td>0.933672</td>
#       <td>0.474279</td>
#       <td>-1.277582</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.152202</td>
#       <td>0.971035</td>
#       <td>0.433178</td>
#       <td>-1.293177</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.118927</td>
#       <td>0.968184</td>
#       <td>0.469997</td>
#       <td>-1.272588</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.073503</td>
#       <td>0.956111</td>
#       <td>0.487898</td>
#       <td>-1.301958</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.044832</td>
#       <td>0.924964</td>
#       <td>0.472049</td>
#       <td>-1.264250</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.990830</td>
#       <td>0.895348</td>
#       <td>0.492225</td>
#       <td>-1.320586</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.960576</td>
#       <td>0.897023</td>
#       <td>0.522089</td>
#       <td>-1.269444</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.910713</td>
#       <td>0.837196</td>
#       <td>0.560682</td>
#       <td>-1.264668</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0
# Better model found at epoch 19 with acc_segmentation value: 0.4878980815410614.
# Better model found at epoch 21 with acc_segmentation value: 0.49222537875175476.
# Better model found at epoch 22 with acc_segmentation value: 0.5220893621444702.
# Better model found at epoch 23 with acc_segmentation value: 0.560681939125061.
# Better model found at epoch 24 with acc_segmentation value: 0.6052843332290649.
# Better model found at epoch 28 with acc_segmentation value: 0.6151237487792969.
# Better model found at epoch 30 with acc_segmentation value: 0.6256796717643738.
# Better model found at epoch 31 with acc_segmentation value: 0.6596283316612244.
# Better model found at epoch 35 with acc_segmentation value: 0.6800514459609985.
# Better model found at epoch 36 with acc_segmentation value: 0.7016457915306091.
# Better model found at epoch 52 with acc_segmentation value: 0.7095679044723511.
# Better model found at epoch 53 with acc_segmentation value: 0.7348798513412476.
# Better model found at epoch 60 with acc_segmentation value: 0.7393260598182678.
# Better model found at epoch 61 with acc_segmentation value: 0.7621921300888062.
# Better model found at epoch 67 with acc_segmentation value: 0.7732369899749756.
# Better model found at epoch 95 with acc_segmentation value: 0.788629949092865.

# %%
# learn.load('stage-1-best')
# learn.save('stage-1-size350-bestEpoch',return_path=True)
# Out:
# PosixPath('database/done/models/stage-1-size350-bestEpoch.pth')

# %%
learn.load('stage-1-size350-bestEpoch')
print(learn.validate())
learn.show_results(figsize=(15,15))
# Out:
# [0.48702335, tensor(0.7886), tensor(-1.1938)]

# %% [markdown]
# # INTERPRETATION

# %%
learn = unet_learner(data, models.resnet34, metrics=[acc_segmentation,dice], wd=wd)
#learn.load('stage-1-size7-8epochs')
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()
#interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=10)

# %% [markdown]
# # FINE-TUNING

# %%
wd=1e-3
learn = unet_learner(data, models.resnet34, metrics=[acc_segmentation,dice_segmentation], wd=wd, callback_fns=ShowGraph).to_fp16()
learn.load('stage-1-size350-bestEpoch')
learn.unfreeze()

# %%
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.00E-05

# %%
# loss sempre crescente para wd 1e-4.
# loss 0.065 para wd 1e-3. Começa aumentar em lr = 1e-4
# loss 0.06 para wd 1e-2. Começa aumentar em lr = 1e-4
lrs = slice(lr/400,lr/4)
#lrs = slice(1e-5,1e-4)

# %%
learn.fit_one_cycle(50, lrs, pct_start=0.3, 
callbacks=[SaveModelCallback(learn, every='improvement', monitor='acc_segmentation',
                                                 name='stage-2-best')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_segmentation</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.150280</td>
#       <td>0.496532</td>
#       <td>0.812603</td>
#       <td>-1.188514</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.149330</td>
#       <td>0.493514</td>
#       <td>0.814599</td>
#       <td>-1.188632</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.144501</td>
#       <td>0.495085</td>
#       <td>0.813514</td>
#       <td>-1.188446</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.144183</td>
#       <td>0.513229</td>
#       <td>0.809337</td>
#       <td>-1.190156</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.143319</td>
#       <td>0.527489</td>
#       <td>0.808910</td>
#       <td>-1.189628</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.143132</td>
#       <td>0.514811</td>
#       <td>0.803531</td>
#       <td>-1.190385</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.142705</td>
#       <td>0.548630</td>
#       <td>0.784149</td>
#       <td>-1.196009</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.144215</td>
#       <td>0.581455</td>
#       <td>0.783655</td>
#       <td>-1.195338</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.143571</td>
#       <td>0.561069</td>
#       <td>0.787032</td>
#       <td>-1.191885</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.141132</td>
#       <td>0.546113</td>
#       <td>0.792840</td>
#       <td>-1.190316</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.139941</td>
#       <td>0.530749</td>
#       <td>0.792399</td>
#       <td>-1.192502</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0
</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.107812</td>
#       <td>0.557670</td>
#       <td>0.803484</td>
#       <td>-1.192529</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.107794</td>
#       <td>0.568551</td>
#       <td>0.798284</td>
#       <td>-1.192733</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.107509</td>
#       <td>0.570291</td>
#       <td>0.799804</td>
#       <td>-1.192525</td>
#       <td>00:15</td>
#     </tr>
# Better model found at epoch 0 with acc_segmentation value: 0.8126026391983032.
# Better model found at epoch 1 with acc_segmentation value: 0.8145988583564758.
# Better model found at epoch 14 with acc_segmentation value: 0.8244810700416565.

# %%
# NAO SALVOU STAGE 2 POIS DEU OVERFITTING. PARAMETROS  DA CNN JA ESTAO BONS POIS VIERAM DO FOOD101
learn.load('stage-2-best')
learn.save('stage-2-size350-bestEpoch')

# %% [markdown]
# # POSPROCESSING

# %%
learn = unet_learner(data, models.resnet34, metrics=[]).to_fp16()
learn.load('stage-2-size350-bestEpoch') 
learn.show_results(figsize=(20,20))

# %%
id2name = {k:v for k,v in enumerate(codes)} # faz uma lista que relaciona nome e id
preds = learn.get_preds(ds_type=DatasetType.Valid)

# %%
index = 20
pred = learn.predict(data.valid_ds.x[index])
pred[0]
# Out:
# ImageSegment (1, 350, 350)

# %%
data.valid_ds.x[index]

# %%
predArray = pred[0].data.numpy() #imagem com os labels de cada pixel
predArray = np.squeeze(predArray,axis=0)
foods, counts = np.unique(predArray,return_counts=True)
counts = np.delete(counts, 0) #tira o void na posicao 0 do array
foods = np.delete(foods, 0) #tira o void na posicao 0 do array
foodNames = []
print(f'Numero de alimentos: {len(foods)}')
for food in foods:
    foodNames = np.append(foodNames,id2name[food])
print(dict(zip(foodNames, counts)))
# Out:
# Numero de alimentos: 16
# {'arroz': 3, 'salada': 13806, 'frango': 15871, 'ovo': 2494, 'pure de batata': 2031, 'tomate': 14400, 'batata': 10969, 'farofa': 28, 'batata frita': 3, 'legumes': 27, 'pepino': 84, 'cenoura': 225, 'beterraba': 35, 'parmegiana': 4, 'strogonoff': 2474, 'linguica': 17}

# %%
print(data.valid_ds.y.items[index])
imgTarget = Image.open(data.valid_ds.y.items[index])
img = imgTarget.resize(np.flip(size))
targArray = np.array(img)
foods, counts = np.unique(targArray,return_counts=True)
counts = np.delete(counts, 0) #tira o void na posicao 0 do array
foods = np.delete(foods, 0) #tira o void na posicao 0 do array
foodNames = []
print(f'Numero de alimentos: {len(foods)}')
for food in foods:
    foodNames = np.append(foodNames,id2name[food])
print(dict(zip(foodNames, counts)))
img
# Out:
# ./database/gt/88GT.png
# Numero de alimentos: 5
# {'salada': 15541, 'frango': 17860, 'pure de batata': 13611, 'tomate': 9930, 'batata': 5743}
# <PIL.Image.Image image mode=L size=350x350 at 0x7F580039F8D0>

# %%
target = preds[1][index].data.numpy()
foods, counts = np.unique(target,return_counts=True)
counts = np.delete(counts, 0) #tira o void na posicao 0 do array
foods = np.delete(foods, 0) #tira o void na posicao 0 do array
accuracy = (target == predArray).mean()
print(accuracy)
# Out:
# 0.7828734693877551

# %% [markdown]
# # PREDICTIONS

# %%
learn = unet_learner(data, models.resnet34, metrics=[acc_segmentation,dice_segmentation])
learn.load('stage-1-size350-466-bestEpoch-accSemVoid') #melhor modelo foi sem unfreeze!
img = data.train_ds[0][0]
learn.predict(img);
img.show(y=learn.predict(img)[0])
